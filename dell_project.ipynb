# %%
import numpy as mp
import pandas as pd
import os
import matplotlib.pyplot as plt
df= pd.read_csv("supermarket_sales.csv", sep=",")
import numpy as mp
import pandas as pd
import os
import matplotlib.pyplot as plt
df= pd.read_csv("supermarket_sales.csv", sep=",")
X=df.iloc[:,4]
Y=df.iloc[:,13]

# %%
plt.bar(X,Y)
plt.xlabel('Product type',fontsize=10)
plt.ylabel('%gross income',fontsize=10)
plt.xticks(rotation=30)
plt.title('Percentage gross income for each product')
plt.show()

# %%
import numpy as mp
import pandas as pd
import os
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
df= pd.read_csv("supermarket_sales.csv", sep=",")
A=df.iloc[:,2:5]
B=df.iloc[:,14]
df1=pd.concat([A,B], axis=1)
km4=KMeans(n_clusters=6,init='k-means++', max_iter=300, n_init=10, random_state=0)
y_means = km4.fit_predict(X)
plt.scatter(X[y_means==0,0],X[y_means==0,1],s=50, c='purple',label='Cluster1')
plt.scatter(X[y_means==1,0],X[y_means==1,1],s=50, c='blue',label='Cluster2')
plt.scatter(X[y_means==2,0],X[y_means==2,1],s=50, c='green',label='Cluster3')
plt.scatter(X[y_means==3,0],X[y_means==3,1],s=50, c='cyan',label='Cluster4')
plt.scatter(X[y_means==4,0],X[y_means==4,1],s=50, c='magenta',label='Cluster5')
plt.scatter(X[y_means==5,0],X[y_means==5,1],s=50, c='orange',label='Cluster6')
plt.scatter(km.cluster_centers_[:,0], km.cluster_centers_[:,1],s=200,marker='s', c='red', alpha=0.7, label='Centroids')
plt.title('Customer segments')
plt.xlabel('Annual income of customer')
plt.ylabel('Annual spend from customer on site')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-9e439d1116fb> in <module>
#       9 df1=pd.concat([A,B], axis=1)
#      10 km4=KMeans(n_clusters=6,init='k-means++', max_iter=300, n_init=10, random_state=0)
# ---> 11 y_means = km4.fit_predict(X)
#      12 plt.scatter(X[y_means==0,0],X[y_means==0,1],s=50, c='purple',label='Cluster1')
#      13 plt.scatter(X[y_means==1,0],X[y_means==1,1],s=50, c='blue',label='Cluster2')
#
# ~\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py in fit_predict(self, X, y, sample_weight)
#     993             Index of the cluster each sample belongs to.
#     994         """
# --> 995         return self.fit(X, sample_weight=sample_weight).labels_
#     996
#     997     def fit_transform(self, X, y=None, sample_weight=None):
#
# ~\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py in fit(self, X, y, sample_weight)
# ...

# %%
import numpy as mp
import pandas as pd
import os
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
df= pd.read_csv("supermarket_sales.csv", sep=",")
df=df.fillna(0)
left_emp =  df[['monthly_income', 'Customer_age']]
# Create groups using K-means clustering.
kmeans = KMeans(n_clusters = 4, random_state = 0).fit(left_emp)
# Add new column "label" annd assign cluster labels.
left_emp['label'] = kmeans.labels_
# Draw scatter plot
plt.scatter(left_emp['monthly_income'], left_emp['Customer_age'], c=left_emp['label'],cmap='Accent')
plt.xlabel('Customer monthly income')
plt.ylabel('Customer age')
plt.title('customer segmentation based on customer age and income')
plt.show()
# Out:
# C:\Users\KIIT\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':

# %%
import numpy as mp
import pandas as pd
import os
import matplotlib.pyplot as plt
df= pd.read_csv("supermarket_sales.csv", sep=",")
X=df.iloc[:,4]
Y=df.iloc[:,13]
df["Gender"]= df["Gender"].replace("Female",1) 
df["Gender"]= df["Gender"].replace("Male",0) 
df["Product_line"]= df["Product_line"].replace("health_gadget",10) 
df["Product_line"]= df["Product_line"].replace("electronics",20) 
df["Product_line"]= df["Product_line"].replace("home_appliances",30) 
df["Product_line"]= df["Product_line"].replace("computers",40) 
df["Product_line"]= df["Product_line"].replace("pendrive",50) 
df["Product_line"]= df["Product_line"].replace("bluetooth",60) 
df["Product_line"]= df["Product_line"].replace("hardisk",70) 
A=df.iloc[:,2:5]
B=df.iloc[:,14]
df1=pd.concat([A,B], axis=1)
left_emp =  df1[['Product_line', 'Customer_age']]
# Create groups using K-means clustering.
kmeans = KMeans(n_clusters = 1, random_state = 0).fit(left_emp)
# Add new column "label" annd assign cluster labels.
left_emp['label'] = kmeans.labels_
# Draw scatter plot
plt.scatter(left_emp['Product_line'], left_emp['Customer_age'], c=left_emp['label'],cmap='Accent')
plt.xlabel('product id')
plt.ylabel('Customer age')
plt.title('customer segmentation based on customer age and product id')
plt.show()
# Out:
# C:\Users\KIIT\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
import numpy as mp
import pandas as pd
import os
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
df= pd.read_csv("supermarket_sales.csv", sep=",")
df=df.fillna(0)
left_emp =  df[['Product_line', 'Customer_age']]
# Create groups using K-means clustering.
kmeans = KMeans(n_clusters = 3, random_state = 0).fit(left_emp)
# Add new column "label" annd assign cluster labels.
left_emp['label'] = kmeans.labels_
# Draw scatter plot
plt.scatter(left_emp['Product_line'], left_emp['Customer_age'], c=left_emp['label'],cmap='Accent')
plt.xlabel('Products')
plt.ylabel('Customer age')
plt.title('customer segmentation based on customer age and product')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-7bd89c2918f7> in <module>
#       8 left_emp =  df[['Product_line', 'Customer_age']]
#       9 # Create groups using K-means clustering.
# ---> 10 kmeans = KMeans(n_clusters = 3, random_state = 0).fit(left_emp)
#      11 # Add new column "label" annd assign cluster labels.
#      12 left_emp['label'] = kmeans.labels_
#
# ~\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py in fit(self, X, y, sample_weight)
#     967                 tol=self.tol, random_state=random_state, copy_x=self.copy_x,
#     968                 n_jobs=self.n_jobs, algorithm=self.algorithm,
# --> 969                 return_n_iter=True)
#     970         return self
#     971
#
# ...

# %%
import numpy as mp
import pandas as pd
import os
import matplotlib.pyplot as plt
df= pd.read_csv("supermarket_sales.csv", sep=",")
X=df.iloc[:,4]
Y=df.iloc[:,13]
df["Gender"]= df["Gender"].replace("Female",1) 
df["Gender"]= df["Gender"].replace("Male",0) 
df["Product_line"]= df["Product_line"].replace("health_gadget",10) 
df["Product_line"]= df["Product_line"].replace("electronics",20) 
df["Product_line"]= df["Product_line"].replace("home_appliances",30) 
df["Product_line"]= df["Product_line"].replace("computers",40) 
df["Product_line"]= df["Product_line"].replace("pendrive",50) 
df["Product_line"]= df["Product_line"].replace("bluetooth",60) 
df["Product_line"]= df["Product_line"].replace("hardisk",70) 
A=df.iloc[:,2:5]
B=df.iloc[:,14]
df1=pd.concat([A,B], axis=1)
left_emp =  df1[['Product_line', 'Gender']]
# Create groups using K-means clustering.
kmeans = KMeans(n_clusters = 1, random_state = 0).fit(left_emp)
# Add new column "label" annd assign cluster labels.
left_emp['label'] = kmeans.labels_
# Draw scatter plot
plt.scatter(left_emp['Product_line'], left_emp['Gender'], c=left_emp['label'],cmap='Accent')
plt.xlabel('product id')
plt.ylabel('Gender')
plt.title('customer segmentation based on customer Gender and Product id')
plt.show()
# Out:
# C:\Users\KIIT\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
import numpy as mp
import pandas as pd
import os
import matplotlib.pyplot as plt
df= pd.read_csv("supermarket_sales.csv", sep=",")
df["Gender"]= df["Gender"].replace("Female",1) 
df["Gender"]= df["Gender"].replace("Male",0) 
X=df.iloc[:,4]
Y=df.iloc[:,3]
plt.bar(X,Y)
plt.xlabel('Product type',fontsize=10)
plt.ylabel('Gender',fontsize=10)
plt.xticks(rotation=30)
plt.title('Gender distribution for each product')
plt.show()

# %%
import numpy as mp
import pandas as pd
import os
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
df= pd.read_csv("supermarket_sales.csv", sep=",")
df=df.fillna(0)
df["Gender"]= df["Gender"].replace("Female",1) 
df["Gender"]= df["Gender"].replace("Male",0) 
km = KMeans(n_clusters=5)
x=df.iloc[:,[2,3,16]]
clusters = km.fit_predict(x)
df["label"] = clusters
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df.Customer_age[df.label == 0], df["monthly_income"][df.label == 0], df["Gender"][df.label == 0], c='blue', s=60)
ax.scatter(df.Customer_age[df.label == 1], df["monthly_income"][df.label == 1], df["Gender"][df.label == 1], c='red', s=60)
ax.scatter(df.Customer_age[df.label == 2], df["monthly_income"][df.label == 2], df["Gender"][df.label == 2], c='green', s=60)
ax.scatter(df.Customer_age[df.label == 3], df["monthly_income"][df.label == 3], df["Gender"][df.label == 3], c='orange', s=60)
ax.scatter(df.Customer_age[df.label == 4], df["monthly_income"][df.label == 4], df["Gender"][df.label == 4], c='purple', s=60)
ax.view_init(30, 185)
plt.xlabel("Age")
plt.ylabel("Monthly Income")
ax.set_zlabel('Gender')
plt.show()

# %%
import numpy as mp
import pandas as pd
import os
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
df= pd.read_csv("supermarket_sales.csv", sep=",")
df=df.fillna(0)
df["Gender"]= df["Gender"].replace("Female",1) 
df["Gender"]= df["Gender"].replace("Male",0)
df["Product_line"]= df["Product_line"].replace("health_gadget",10) 
df["Product_line"]= df["Product_line"].replace("electronics",20) 
df["Product_line"]= df["Product_line"].replace("home_appliances",30) 
df["Product_line"]= df["Product_line"].replace("computers",40) 
df["Product_line"]= df["Product_line"].replace("pendrive",50) 
df["Product_line"]= df["Product_line"].replace("bluetooth",60) 
df["Product_line"]= df["Product_line"].replace("hardisk",70) 
km = KMeans(n_clusters=5)
x=df.iloc[:,[2,4,16]]
clusters = km.fit_predict(x)
df["label"] = clusters
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df.Customer_age[df.label == 0], df["monthly_income"][df.label == 0], df["Product_line"][df.label == 0], c='blue', s=60)
ax.scatter(df.Customer_age[df.label == 1], df["monthly_income"][df.label == 1], df["Product_line"][df.label == 1], c='red', s=60)
ax.scatter(df.Customer_age[df.label == 2], df["monthly_income"][df.label == 2], df["Product_line"][df.label == 2], c='green', s=60)
ax.scatter(df.Customer_age[df.label == 3], df["monthly_income"][df.label == 3], df["Product_line"][df.label == 3], c='orange', s=60)
ax.scatter(df.Customer_age[df.label == 4], df["monthly_income"][df.label == 4], df["Product_line"][df.label == 4], c='purple', s=60)
ax.view_init(30, 185)
plt.xlabel("Age")
plt.ylabel("Monthly Income")
ax.set_zlabel('product Id')
plt.show()
